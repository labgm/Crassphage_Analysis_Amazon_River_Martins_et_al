# %% [markdown]
# # Plot alpha diversity graphics

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your data
alpha = pd.read_csv('/home/davidmartins/Documentos/Viral_analysis/diversity_analysis/diversity_data_table.tsv', sep='\t')

custom_colors = ['#D81B60', '#1E88E5', '#FFC107', '#004D40'] 
# Set the theme for the plots
sns.set_theme(style="white")

# Create a figure and two subplots
plt.figure(figsize=(10, 5))  # Adjust figure size

# First subplot
plt.subplot(1, 2, 1)  # 1 row, 2 columns, second subplot
sns.boxplot(x="samples", y="Shannon", data=alpha, palette=custom_colors)  # Assume 'Shannon' is another diversity measure
plt.xlabel("Sample Names")
plt.ylabel("Shannon Diversity Index")
#plt.title("Shannon Index Boxplot")

# Second subplot
plt.subplot(1, 2, 2)  # 1 row, 2 columns, first subplot
sns.boxplot(x="samples", y="Observed", data=alpha, palette=custom_colors)
plt.xlabel("Sample Names")
plt.ylabel("Richness")
#plt.title("Simpson Index Boxplot")


# Adjust the layout to avoid overlapping plots
plt.tight_layout()

plt.show()
# Out:
# /tmp/ipykernel_36708/3725245004.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="samples", y="Shannon", data=alpha, palette=custom_colors)  # Assume 'Shannon' is another diversity measure
# /tmp/ipykernel_36708/3725245004.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="samples", y="Observed", data=alpha, palette=custom_colors)

# %% [markdown]
# # Plot clustermap

# %%
import pandas as pd
import numpy as np
from bioinfokit.analys import norm, get_data
import seaborn as sns
import matplotlib.pyplot as plt

#Path to file with crassphage log transformed abundances
df = pd.read_csv('/home/davidmartins/Documentos/Viral_analysis/crass_genomad/clust_heatmap/crAss_log_trans.tsv', sep='\t')

# Save the row and column labels before converting to numeric
row_labels = df_transposed.index
col_labels = df_transposed.columns

# Convert to numeric, ignoring errors to avoid non-numeric data
df_transposed_numeric = df_transposed.apply(pd.to_numeric, errors='coerce')

# Drop rows or columns with NaNs if necessary
df_transposed_numeric = df_transposed_numeric.dropna(how='any')

# Create the clustermap with labels for the axes
sns.clustermap(df_transposed_numeric, cmap="viridis", linewidths=0.2, figsize=(8, 12), linecolor='black', 
                xticklabels=col_labels, yticklabels=row_labels)
